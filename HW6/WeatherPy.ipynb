# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "72392c5eb9d98af1b4bef53fec781aa9"

# List of city data
city_data = []

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found.")
        pass
# Out:
# Processing Record 1 of Set 1 | little current
# Processing Record 2 of Set 1 | cape town
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | gbarnga
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | potsdam
# Processing Record 8 of Set 1 | cozumel
# City not found.
# Processing Record 9 of Set 1 | kumluca
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | kirakira
# Processing Record 15 of Set 1 | nizhneyansk
# City not found.
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | khunti
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | punahana
# Processing Record 22 of Set 1 | flin flon
# Processing Record 23 of Set 1 | guerrero negro
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | mys shmidta
# City not found.
# Processing Record 26 of Set 1 | kattivakkam
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | sitka
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | port blair
# Processing Record 31 of Set 1 | ereymentau
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | laguna
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | illoqqortoormiut
# City not found.
# Processing Record 36 of Set 1 | huarmey
# Processing Record 37 of Set 1 | sungaipenuh
# Processing Record 38 of Set 1 | tiznit
# Processing Record 39 of Set 1 | bousso
# City not found.
# Processing Record 40 of Set 1 | bilibino
# Processing Record 41 of Set 1 | belaya gora
# Processing Record 42 of Set 1 | neuquen
# Processing Record 43 of Set 1 | ritini
# Processing Record 44 of Set 1 | darhan
# Processing Record 45 of Set 1 | komsomolskiy
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | barrow
# Processing Record 49 of Set 1 | ballina
# Processing Record 50 of Set 1 | hermanus
# Processing Record 0 of Set 2 | booue
# Processing Record 1 of Set 2 | balikpapan
# Processing Record 2 of Set 2 | takoradi
# Processing Record 3 of Set 2 | otradnoye
# Processing Record 4 of Set 2 | karaul
# City not found.
# Processing Record 5 of Set 2 | comodoro rivadavia
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | pangnirtung
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | springbok
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | onokhoy
# Processing Record 14 of Set 2 | saskylakh
# Processing Record 15 of Set 2 | surt
# Processing Record 16 of Set 2 | porto novo
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | airai
# Processing Record 19 of Set 2 | akdagmadeni
# Processing Record 20 of Set 2 | san quintin
# Processing Record 21 of Set 2 | kariba
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | basqal
# Processing Record 24 of Set 2 | hervey bay
# Processing Record 25 of Set 2 | dikson
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | saint-prosper
# Processing Record 28 of Set 2 | ormara
# Processing Record 29 of Set 2 | rumoi
# Processing Record 30 of Set 2 | sept-iles
# Processing Record 31 of Set 2 | leua
# Processing Record 32 of Set 2 | tautira
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | murgab
# Processing Record 35 of Set 2 | kununurra
# Processing Record 36 of Set 2 | viedma
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | torquay
# Processing Record 39 of Set 2 | sundarnagar
# Processing Record 40 of Set 2 | zabol
# Processing Record 41 of Set 2 | skibbereen
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | bud
# Processing Record 44 of Set 2 | khuzhir
# Processing Record 45 of Set 2 | severo-kurilsk
# Processing Record 46 of Set 2 | aksarka
# Processing Record 47 of Set 2 | fairbanks
# Processing Record 48 of Set 2 | flinders
# Processing Record 49 of Set 2 | lorengau
# Processing Record 0 of Set 3 | kapaa
# Processing Record 1 of Set 3 | taolanaro
# City not found.
# Processing Record 2 of Set 3 | opuwo
# Processing Record 3 of Set 3 | guarda
# Processing Record 4 of Set 3 | esso
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | thompson
# Processing Record 7 of Set 3 | sesimbra
# Processing Record 8 of Set 3 | dillon
# Processing Record 9 of Set 3 | mocambique
# City not found.
# Processing Record 10 of Set 3 | bluff
# Processing Record 11 of Set 3 | marcona
# City not found.
# Processing Record 12 of Set 3 | longyearbyen
# Processing Record 13 of Set 3 | tuatapere
# Processing Record 14 of Set 3 | verkhnetulomskiy
# Processing Record 15 of Set 3 | bagua grande
# Processing Record 16 of Set 3 | zheshart
# Processing Record 17 of Set 3 | finschhafen
# Processing Record 18 of Set 3 | malwan
# City not found.
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | kruisfontein
# Processing Record 21 of Set 3 | carlisle
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | coahuayana
# Processing Record 24 of Set 3 | moroceli
# Processing Record 25 of Set 3 | puerto ayora
# Processing Record 26 of Set 3 | novaya igirma
# Processing Record 27 of Set 3 | akyab
# City not found.
# Processing Record 28 of Set 3 | mul
# Processing Record 29 of Set 3 | yulara
# Processing Record 30 of Set 3 | christchurch
# Processing Record 31 of Set 3 | san jose
# Processing Record 32 of Set 3 | torbay
# Processing Record 33 of Set 3 | tazovskiy
# Processing Record 34 of Set 3 | yar-sale
# Processing Record 35 of Set 3 | carnarvon
# Processing Record 36 of Set 3 | port macquarie
# Processing Record 37 of Set 3 | iona
# Processing Record 38 of Set 3 | north bend
# Processing Record 39 of Set 3 | broome
# Processing Record 40 of Set 3 | alta floresta
# Processing Record 41 of Set 3 | puerto escondido
# Processing Record 42 of Set 3 | marsh harbour
# Processing Record 43 of Set 3 | lavrentiya
# Processing Record 44 of Set 3 | urengoy
# Processing Record 45 of Set 3 | katsiveli
# City not found.
# Processing Record 46 of Set 3 | sola
# Processing Record 47 of Set 3 | sorvag
# City not found.
# Processing Record 48 of Set 3 | uvira
# Processing Record 49 of Set 3 | la asuncion
# Processing Record 0 of Set 4 | bathsheba
# Processing Record 1 of Set 4 | guilin
# Processing Record 2 of Set 4 | correntina
# Processing Record 3 of Set 4 | sorel
# Processing Record 4 of Set 4 | ahuimanu
# Processing Record 5 of Set 4 | nikolskoye
# Processing Record 6 of Set 4 | basco
# Processing Record 7 of Set 4 | rio de janeiro
# Processing Record 8 of Set 4 | isangel
# Processing Record 9 of Set 4 | deputatskiy
# Processing Record 10 of Set 4 | dingle
# Processing Record 11 of Set 4 | goryachiy klyuch
# Processing Record 12 of Set 4 | mesyagutovo
# Processing Record 13 of Set 4 | avarua
# Processing Record 14 of Set 4 | nogales
# Processing Record 15 of Set 4 | juxian
# City not found.
# Processing Record 16 of Set 4 | antofagasta
# Processing Record 17 of Set 4 | roanoke rapids
# Processing Record 18 of Set 4 | ancud
# Processing Record 19 of Set 4 | amderma
# City not found.
# Processing Record 20 of Set 4 | acarau
# City not found.
# Processing Record 21 of Set 4 | hamilton
# Processing Record 22 of Set 4 | gayeri
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | busselton
# Processing Record 25 of Set 4 | prince rupert
# Processing Record 26 of Set 4 | grindavik
# Processing Record 27 of Set 4 | thano bula khan
# City not found.
# Processing Record 28 of Set 4 | souillac
# Processing Record 29 of Set 4 | sassenberg
# Processing Record 30 of Set 4 | hofn
# Processing Record 31 of Set 4 | totness
# Processing Record 32 of Set 4 | atambua
# Processing Record 33 of Set 4 | lagoa
# Processing Record 34 of Set 4 | bairiki
# City not found.
# Processing Record 35 of Set 4 | turukhansk
# Processing Record 36 of Set 4 | belyy yar
# Processing Record 37 of Set 4 | rocha
# Processing Record 38 of Set 4 | halalo
# City not found.
# Processing Record 39 of Set 4 | taitung
# Processing Record 40 of Set 4 | george
# Processing Record 41 of Set 4 | tolaga bay
# Processing Record 42 of Set 4 | mackenzie
# Processing Record 43 of Set 4 | kavieng
# Processing Record 44 of Set 4 | chokurdakh
# Processing Record 45 of Set 4 | bengkulu
# City not found.
# Processing Record 46 of Set 4 | saint anthony
# Processing Record 47 of Set 4 | colesberg
# Processing Record 48 of Set 4 | longlac
# City not found.
# Processing Record 49 of Set 4 | bugiri
# Processing Record 0 of Set 5 | attawapiskat
# City not found.
# Processing Record 1 of Set 5 | ponta do sol
# Processing Record 2 of Set 5 | san andres
# Processing Record 3 of Set 5 | teixoso
# Processing Record 4 of Set 5 | burnie
# Processing Record 5 of Set 5 | korla
# City not found.
# Processing Record 6 of Set 5 | moree
# Processing Record 7 of Set 5 | cabinda
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | saint george
# Processing Record 11 of Set 5 | ilulissat
# Processing Record 12 of Set 5 | cap malheureux
# Processing Record 13 of Set 5 | sisimiut
# Processing Record 14 of Set 5 | provideniya
# Processing Record 15 of Set 5 | whitehorse
# Processing Record 16 of Set 5 | zhigansk
# Processing Record 17 of Set 5 | praia
# Processing Record 18 of Set 5 | kaitangata
# Processing Record 19 of Set 5 | ngunguru
# Processing Record 20 of Set 5 | kuala terengganu
# Processing Record 21 of Set 5 | tumannyy
# City not found.
# Processing Record 22 of Set 5 | bolobo
# Processing Record 23 of Set 5 | berlevag
# Processing Record 24 of Set 5 | chapais
# Processing Record 25 of Set 5 | yertsevo
# Processing Record 26 of Set 5 | havoysund
# Processing Record 27 of Set 5 | taltal
# Processing Record 28 of Set 5 | novyy urengoy
# Processing Record 29 of Set 5 | gao
# Processing Record 30 of Set 5 | port augusta
# Processing Record 31 of Set 5 | mmabatho
# Processing Record 32 of Set 5 | vaitupu
# City not found.
# Processing Record 33 of Set 5 | upernavik
# Processing Record 34 of Set 5 | bawku
# Processing Record 35 of Set 5 | bonthe
# Processing Record 36 of Set 5 | keita
# Processing Record 37 of Set 5 | dharan
# Processing Record 38 of Set 5 | great yarmouth
# Processing Record 39 of Set 5 | bayeux
# Processing Record 40 of Set 5 | aflu
# City not found.
# Processing Record 41 of Set 5 | chicama
# Processing Record 42 of Set 5 | makakilo city
# Processing Record 43 of Set 5 | oranjemund
# Processing Record 44 of Set 5 | faanui
# Processing Record 45 of Set 5 | narsaq
# Processing Record 46 of Set 5 | leningradskiy
# Processing Record 47 of Set 5 | muisne
# Processing Record 48 of Set 5 | campoverde
# Processing Record 49 of Set 5 | minab
# Processing Record 0 of Set 6 | cherskiy
# Processing Record 1 of Set 6 | miles city
# Processing Record 2 of Set 6 | zhitikara
# City not found.
# Processing Record 3 of Set 6 | grand river south east
# City not found.
# Processing Record 4 of Set 6 | avera
# Processing Record 5 of Set 6 | falealupo
# City not found.
# Processing Record 6 of Set 6 | half moon bay
# Processing Record 7 of Set 6 | hithadhoo
# Processing Record 8 of Set 6 | margate
# Processing Record 9 of Set 6 | chuy
# Processing Record 10 of Set 6 | necochea
# Processing Record 11 of Set 6 | yatou
# Processing Record 12 of Set 6 | sawtell
# Processing Record 13 of Set 6 | waingapu
# Processing Record 14 of Set 6 | soyo
# Processing Record 15 of Set 6 | hobyo
# Processing Record 16 of Set 6 | wampusirpi
# City not found.
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | beisfjord
# Processing Record 19 of Set 6 | kamenka
# Processing Record 20 of Set 6 | teya
# Processing Record 21 of Set 6 | rundu
# Processing Record 22 of Set 6 | buchanan
# Processing Record 23 of Set 6 | wankaner
# Processing Record 24 of Set 6 | ocu
# Processing Record 25 of Set 6 | lazaro cardenas
# Processing Record 26 of Set 6 | nabire
# Processing Record 27 of Set 6 | adrar
# Processing Record 28 of Set 6 | hanyang
# Processing Record 29 of Set 6 | sentyabrskiy
# City not found.
# Processing Record 30 of Set 6 | saint-francois
# Processing Record 31 of Set 6 | belushya guba
# City not found.
# Processing Record 32 of Set 6 | lompoc
# Processing Record 33 of Set 6 | mersing
# Processing Record 34 of Set 6 | karratha
# Processing Record 35 of Set 6 | ahipara
# Processing Record 36 of Set 6 | chipinge
# Processing Record 37 of Set 6 | santa maria
# Processing Record 38 of Set 6 | aksu
# Processing Record 39 of Set 6 | port lincoln
# Processing Record 40 of Set 6 | maarianhamina
# City not found.
# Processing Record 41 of Set 6 | kuldur
# Processing Record 42 of Set 6 | dunedin
# Processing Record 43 of Set 6 | anadyr
# Processing Record 44 of Set 6 | richards bay
# Processing Record 45 of Set 6 | marawi
# Processing Record 46 of Set 6 | nangong
# Processing Record 47 of Set 6 | caravelas
# Processing Record 48 of Set 6 | koungou
# City not found.
# Processing Record 49 of Set 6 | esperance
# Processing Record 0 of Set 7 | walvis bay
# Processing Record 1 of Set 7 | hirara
# Processing Record 2 of Set 7 | wanning
# Processing Record 3 of Set 7 | poronaysk
# Processing Record 4 of Set 7 | chinhoyi
# Processing Record 5 of Set 7 | tabiauea
# City not found.
# Processing Record 6 of Set 7 | isiro
# Processing Record 7 of Set 7 | coron
# Processing Record 8 of Set 7 | mahebourg
# Processing Record 9 of Set 7 | morant bay
# Processing Record 10 of Set 7 | dumai
# Processing Record 11 of Set 7 | enumclaw
# Processing Record 12 of Set 7 | san patricio
# Processing Record 13 of Set 7 | labutta
# City not found.
# Processing Record 14 of Set 7 | laiyang
# Processing Record 15 of Set 7 | goure
# Processing Record 16 of Set 7 | ostrovnoy
# Processing Record 17 of Set 7 | schenectady
# Processing Record 18 of Set 7 | pevek
# Processing Record 19 of Set 7 | la llanada
# Processing Record 20 of Set 7 | kieta
# Processing Record 21 of Set 7 | birsk
# Processing Record 22 of Set 7 | khormuj
# City not found.
# Processing Record 23 of Set 7 | urumqi
# City not found.
# Processing Record 24 of Set 7 | abu dhabi
# Processing Record 25 of Set 7 | gulshat
# City not found.
# Processing Record 26 of Set 7 | mandalgovi
# Processing Record 27 of Set 7 | mitchell
# Processing Record 28 of Set 7 | vila franca do campo
# Processing Record 29 of Set 7 | ambilobe
# Processing Record 30 of Set 7 | barentsburg
# City not found.
# Processing Record 31 of Set 7 | aragarcas
# Processing Record 32 of Set 7 | ningan
# City not found.
# Processing Record 33 of Set 7 | bafia
# Processing Record 34 of Set 7 | hambantota
# Processing Record 35 of Set 7 | saurimo
# Processing Record 36 of Set 7 | svidnik
# Processing Record 37 of Set 7 | doha
# Processing Record 38 of Set 7 | tarko-sale
# Processing Record 39 of Set 7 | sur
# Processing Record 40 of Set 7 | saint-pierre
# Processing Record 41 of Set 7 | pisco
# Processing Record 42 of Set 7 | oranzherei
# Processing Record 43 of Set 7 | byron bay
# Processing Record 44 of Set 7 | maku
# Processing Record 45 of Set 7 | fortuna
# Processing Record 46 of Set 7 | dapaong
# Processing Record 47 of Set 7 | lasa
# Processing Record 48 of Set 7 | wajir
# Processing Record 49 of Set 7 | londrina
# Processing Record 0 of Set 8 | santiago
# Processing Record 1 of Set 8 | dogondoutchi
# Processing Record 2 of Set 8 | dolbeau
# City not found.
# Processing Record 3 of Set 8 | balad
# Processing Record 4 of Set 8 | hohhot
# Processing Record 5 of Set 8 | swellendam
# Processing Record 6 of Set 8 | memphis
# Processing Record 7 of Set 8 | port elizabeth
# Processing Record 8 of Set 8 | tsihombe
# City not found.
# Processing Record 9 of Set 8 | gurupi
# Processing Record 10 of Set 8 | canmaya
# City not found.
# Processing Record 11 of Set 8 | zaoyang
# Processing Record 12 of Set 8 | asau
# City not found.
# Processing Record 13 of Set 8 | dawei
# Processing Record 14 of Set 8 | namibe
# Processing Record 15 of Set 8 | pitea
# Processing Record 16 of Set 8 | sao filipe
# Processing Record 17 of Set 8 | andijon
# Processing Record 18 of Set 8 | salekhard
# Processing Record 19 of Set 8 | bulungu
# Processing Record 20 of Set 8 | amuntai
# Processing Record 21 of Set 8 | qaqortoq
# Processing Record 22 of Set 8 | chuzhou
# Processing Record 23 of Set 8 | alexandria
# Processing Record 24 of Set 8 | husavik
# Processing Record 25 of Set 8 | pauini
# Processing Record 26 of Set 8 | norman wells
# Processing Record 27 of Set 8 | warqla
# City not found.
# Processing Record 28 of Set 8 | chebarkul
# Processing Record 29 of Set 8 | nanortalik
# Processing Record 30 of Set 8 | aquiraz
# Processing Record 31 of Set 8 | emborion
# Processing Record 32 of Set 8 | shingu
# Processing Record 33 of Set 8 | shimonoseki
# Processing Record 34 of Set 8 | svetlaya
# Processing Record 35 of Set 8 | kitui
# Processing Record 36 of Set 8 | rock sound
# Processing Record 37 of Set 8 | golden
# Processing Record 38 of Set 8 | agua verde
# Processing Record 39 of Set 8 | arlit
# Processing Record 40 of Set 8 | kabare
# Processing Record 41 of Set 8 | bogande
# Processing Record 42 of Set 8 | iqaluit
# Processing Record 43 of Set 8 | russell
# Processing Record 44 of Set 8 | yanam
# Processing Record 45 of Set 8 | entre rios
# Processing Record 46 of Set 8 | matara
# Processing Record 47 of Set 8 | talnakh
# Processing Record 48 of Set 8 | yucaipa
# Processing Record 49 of Set 8 | port shepstone
# Processing Record 0 of Set 9 | chumikan
# Processing Record 1 of Set 9 | ugra
# Processing Record 2 of Set 9 | pemangkat
# City not found.
# Processing Record 3 of Set 9 | nouadhibou
# Processing Record 4 of Set 9 | chirongui
# Processing Record 5 of Set 9 | mackay
# Processing Record 6 of Set 9 | north myrtle beach
# Processing Record 7 of Set 9 | aleksandrovskiy zavod
# Processing Record 8 of Set 9 | tiksi
# Processing Record 9 of Set 9 | scarborough
# Processing Record 10 of Set 9 | ulladulla
# Processing Record 11 of Set 9 | pacific grove
# Processing Record 12 of Set 9 | galdar
# Processing Record 13 of Set 9 | nhulunbuy
# Processing Record 14 of Set 9 | yanan
# City not found.
# Processing Record 15 of Set 9 | mount gambier
# Processing Record 16 of Set 9 | coihaique
# Processing Record 17 of Set 9 | ituni
# City not found.
# Processing Record 18 of Set 9 | harper
# Processing Record 19 of Set 9 | kampene
# Processing Record 20 of Set 9 | calvinia
# Processing Record 21 of Set 9 | inirida
# Processing Record 22 of Set 9 | machachi
# Processing Record 23 of Set 9 | jacksonville
# Processing Record 24 of Set 9 | najran
# Processing Record 25 of Set 9 | alofi
# Processing Record 26 of Set 9 | itupiranga
# Processing Record 27 of Set 9 | phuntsholing
# Processing Record 28 of Set 9 | meulaboh
# Processing Record 29 of Set 9 | bubaque
# Processing Record 30 of Set 9 | kropotkin
# Processing Record 31 of Set 9 | revelstoke
# Processing Record 32 of Set 9 | rantepao
# Processing Record 33 of Set 9 | balezino
# Processing Record 34 of Set 9 | jumla
# Processing Record 35 of Set 9 | solnechnyy
# Processing Record 36 of Set 9 | karamea
# City not found.
# Processing Record 37 of Set 9 | tadine
# Processing Record 38 of Set 9 | burica
# City not found.
# Processing Record 39 of Set 9 | umzimvubu
# City not found.
# Processing Record 40 of Set 9 | mujiayingzi
# Processing Record 41 of Set 9 | tual
# Processing Record 42 of Set 9 | pangkalanbuun
# Processing Record 43 of Set 9 | honningsvag
# Processing Record 44 of Set 9 | kahului
# Processing Record 45 of Set 9 | reims
# Processing Record 46 of Set 9 | orlovskiy
# Processing Record 47 of Set 9 | karoi
# Processing Record 48 of Set 9 | lypnyazhka
# Processing Record 49 of Set 9 | karkaralinsk
# City not found.
# Processing Record 0 of Set 10 | labrea
# City not found.
# Processing Record 1 of Set 10 | ponta delgada
# Processing Record 2 of Set 10 | palmer
# Processing Record 3 of Set 10 | saryshagan
# City not found.
# Processing Record 4 of Set 10 | achisay
# City not found.
# Processing Record 5 of Set 10 | tilichiki
# Processing Record 6 of Set 10 | prado
# Processing Record 7 of Set 10 | dukat
# Processing Record 8 of Set 10 | clermont
# Processing Record 9 of Set 10 | ferraz de vasconcelos
# Processing Record 10 of Set 10 | atasu
# Processing Record 11 of Set 10 | galesong
# Processing Record 12 of Set 10 | merauke
# Processing Record 13 of Set 10 | bolshaya chernigovka
# City not found.
# Processing Record 14 of Set 10 | porbandar
# Processing Record 15 of Set 10 | halifax
# Processing Record 16 of Set 10 | xining
# Processing Record 17 of Set 10 | ngukurr
# City not found.
# Processing Record 18 of Set 10 | port hardy
# Processing Record 19 of Set 10 | singapore
# Processing Record 20 of Set 10 | oktyabrskiy
# Processing Record 21 of Set 10 | luanda
# Processing Record 22 of Set 10 | gorbehaza
# Processing Record 23 of Set 10 | vernon
# Processing Record 24 of Set 10 | hollister
# Processing Record 25 of Set 10 | surman
# Processing Record 26 of Set 10 | tevriz
# Processing Record 27 of Set 10 | oranjestad
# Processing Record 28 of Set 10 | cuamba
# Processing Record 29 of Set 10 | katangli
# Processing Record 30 of Set 10 | san cristobal
# Processing Record 31 of Set 10 | codrington
# Processing Record 32 of Set 10 | temaraia
# City not found.
# Processing Record 33 of Set 10 | tugalan
# City not found.
# Processing Record 34 of Set 10 | college
# Processing Record 35 of Set 10 | ojinaga
# Processing Record 36 of Set 10 | krasnoselkup
# City not found.
# Processing Record 37 of Set 10 | mileb
# Processing Record 38 of Set 10 | thanesar
# Processing Record 39 of Set 10 | lolua
# City not found.
# Processing Record 40 of Set 10 | maceio
# Processing Record 41 of Set 10 | jurm
# Processing Record 42 of Set 10 | samusu
# City not found.
# Processing Record 43 of Set 10 | albanel
# Processing Record 44 of Set 10 | alberton
# Processing Record 45 of Set 10 | vardo
# Processing Record 46 of Set 10 | ingleside
# Processing Record 47 of Set 10 | ardakan
# Processing Record 48 of Set 10 | bani walid
# Processing Record 49 of Set 10 | natitingou
# Processing Record 0 of Set 11 | baleshwar
# Processing Record 1 of Set 11 | paamiut
# Processing Record 2 of Set 11 | tonantins
# Processing Record 3 of Set 11 | san vicente
# Processing Record 4 of Set 11 | olafsvik
# City not found.
# Processing Record 5 of Set 11 | hongan
# City not found.
# Processing Record 6 of Set 11 | tanem
# Processing Record 7 of Set 11 | vila velha
# Processing Record 8 of Set 11 | langxiang
# Processing Record 9 of Set 11 | huescar
# Processing Record 10 of Set 11 | batagay-alyta
# Processing Record 11 of Set 11 | faya
# Processing Record 12 of Set 11 | amarante do maranhao
# Processing Record 13 of Set 11 | jalu
# Processing Record 14 of Set 11 | okhotsk
# Processing Record 15 of Set 11 | rio verde de mato grosso
# Processing Record 16 of Set 11 | luderitz
# Processing Record 17 of Set 11 | cienaga
# Processing Record 18 of Set 11 | saldanha
# Processing Record 19 of Set 11 | naryan-mar
# Processing Record 20 of Set 11 | nicoya
# Processing Record 21 of Set 11 | kashan
# Processing Record 22 of Set 11 | manuk mangkaw
# Processing Record 23 of Set 11 | wattegama
# Processing Record 24 of Set 11 | miri
# Processing Record 25 of Set 11 | matagami
# Processing Record 26 of Set 11 | smithers
# Processing Record 27 of Set 11 | sorland
# Processing Record 28 of Set 11 | yamada
# Processing Record 29 of Set 11 | inta
# Processing Record 30 of Set 11 | kutulik
# Processing Record 31 of Set 11 | kaeo
# Processing Record 32 of Set 11 | sun valley
# Processing Record 33 of Set 11 | atar
# Processing Record 34 of Set 11 | yeppoon
# Processing Record 35 of Set 11 | verkhnevilyuysk
# Processing Record 36 of Set 11 | monastyrshchina
# Processing Record 37 of Set 11 | xichang
# Processing Record 38 of Set 11 | nha trang
# Processing Record 39 of Set 11 | marienburg
# Processing Record 40 of Set 11 | tynda
# Processing Record 41 of Set 11 | mabaruma
# Processing Record 42 of Set 11 | linxia
# Processing Record 43 of Set 11 | lamar
# Processing Record 44 of Set 11 | fukue
# Processing Record 45 of Set 11 | yovon
# Processing Record 46 of Set 11 | segovia
# Processing Record 47 of Set 11 | kitgum
# Processing Record 48 of Set 11 | tessalit
# Processing Record 49 of Set 11 | boyolangu
# Processing Record 0 of Set 12 | camana
# City not found.
# Processing Record 1 of Set 12 | muriti
# Processing Record 2 of Set 12 | maturin
# Processing Record 3 of Set 12 | bac lieu
# City not found.
# Processing Record 4 of Set 12 | rio branco
# Processing Record 5 of Set 12 | lata
# Processing Record 6 of Set 12 | naze
# Processing Record 7 of Set 12 | tarakan
# Processing Record 8 of Set 12 | tuggurt
# City not found.
# Processing Record 9 of Set 12 | nortelandia
# Processing Record 10 of Set 12 | kloulklubed
# Processing Record 11 of Set 12 | nizwa
# Processing Record 12 of Set 12 | sampit
# Processing Record 13 of Set 12 | namatanai
# Processing Record 14 of Set 12 | uarini
# Processing Record 15 of Set 12 | yangambi
# Processing Record 16 of Set 12 | kadoma
# Processing Record 17 of Set 12 | summerville
# Processing Record 18 of Set 12 | lubango
# Processing Record 19 of Set 12 | springfield
# Processing Record 20 of Set 12 | nguiu
# City not found.
# Processing Record 21 of Set 12 | nguru
# Processing Record 22 of Set 12 | los llanos de aridane
# Processing Record 23 of Set 12 | kintinku
# Processing Record 24 of Set 12 | kaabong
# Processing Record 25 of Set 12 | salantai
# Processing Record 26 of Set 12 | derzhavinsk
# Processing Record 27 of Set 12 | spornoye
# Processing Record 28 of Set 12 | uige
# Processing Record 29 of Set 12 | simao
# Processing Record 30 of Set 12 | venkatagiri
# Processing Record 31 of Set 12 | cockburn town
# Processing Record 32 of Set 12 | kuche
# City not found.
# Processing Record 33 of Set 12 | axim
# Processing Record 34 of Set 12 | ust-nera
# Processing Record 35 of Set 12 | bambous virieux
# Processing Record 36 of Set 12 | requena
# Processing Record 37 of Set 12 | huilong
# Processing Record 38 of Set 12 | jaque
# City not found.
# Processing Record 39 of Set 12 | juneau
# Processing Record 40 of Set 12 | sorong
# Processing Record 41 of Set 12 | samarkand
# Processing Record 42 of Set 12 | talcahuano
# Processing Record 43 of Set 12 | utete
# Processing Record 44 of Set 12 | ruatoria
# City not found.
# Processing Record 45 of Set 12 | nome
# Processing Record 46 of Set 12 | kondopoga
# Processing Record 47 of Set 12 | mbandaka
# Processing Record 48 of Set 12 | mach
# Processing Record 49 of Set 12 | cam ranh
# Processing Record 0 of Set 13 | nikolayevsk-na-amure
# Processing Record 1 of Set 13 | nchelenge
# Processing Record 2 of Set 13 | vestmannaeyjar
# Processing Record 3 of Set 13 | katha
# City not found.
# Processing Record 4 of Set 13 | clyde river
# Processing Record 5 of Set 13 | kristiinankaupunki
# City not found.
# Processing Record 6 of Set 13 | mizan teferi
# Processing Record 7 of Set 13 | mayumba
# Processing Record 8 of Set 13 | marsabit
# Processing Record 9 of Set 13 | wajima
# Processing Record 10 of Set 13 | baykit
# Processing Record 11 of Set 13 | la puebla del rio
# Processing Record 12 of Set 13 | algiers
# Processing Record 13 of Set 13 | vila
# Processing Record 14 of Set 13 | treinta y tres
# Processing Record 15 of Set 13 | guaraniacu
# Processing Record 16 of Set 13 | san joaquin
# Processing Record 17 of Set 13 | rio grande
# Processing Record 18 of Set 13 | nyurba
# Processing Record 19 of Set 13 | bridgetown

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          546
# Cloudiness    546
# Country       546
# Date          546
# Humidity      546
# Lat           546
# Lng           546
# Max Temp      546
# Wind Speed    546
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  little current          20      CA  1571094823        70  45.98  -81.93
# 1       cape town          20      ZA  1571094823        87 -33.93   18.42
# 2  saint-philippe          90      CA  1571094823        76  45.36  -73.48
# 3      butaritari          86      KI  1571094823        64   3.07  172.79
# 4         gbarnga          26      LR  1571094824        99   7.00   -9.47
#
#    Max Temp  Wind Speed
# 0     46.40       21.92
# 1     63.00        5.82
# 2     53.60        8.84
# 3     85.14        6.65
# 4     70.34        0.38

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
